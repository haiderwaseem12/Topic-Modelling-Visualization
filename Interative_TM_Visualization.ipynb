# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
root_path = 'gdrive/My Drive/Covid Project TGPPP/'

# %%
import pickle

# Gensim
import gensim, spacy, logging, warnings
from gensim import models, corpora

# !pip install pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

# %%
#Importing the required files
country = 'India/'
lda_model = models.LdaModel.load(root_path + country + '/lda.model')
corpus = pickle.load(open(root_path + country + 'corpus.pkl', 'rb'))
id2word = gensim.utils.SaveLoad.load(root_path + country + 'dictionary.gensim') 

#Visualising Topic Model
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.061544  0.151427       1        1  20.946495
# 4      0.124489  0.289584       2        1  20.109394
# 3     -0.420699 -0.014218       3        1  19.946367
# 0      0.106254 -0.155899       4        1  19.550127
# 1      0.128413 -0.270893       5        1  19.447617, topic_info=              Term          Freq         Total Category  logprob  loglift
# 23            case  53682.000000  53682.000000  Default  30.0000  30.0000
# 25           virus  34636.000000  34636.000000  Default  29.0000  29.0000
# 35             new  30285.000000  30285.000000  Default  28.0000  28.0000
# 109         people  30057.000000  30057.000000  Default  27.0000  27.0000
# 18           death  25603.000000  25603.000000  Default  26.0000  26.0000
# ...            ...           ...           ...      ...      ...      ...
# 207           real   2258.429443   2259.245117   Topic5  -5.2290   1.6371
# 1239      question   2266.452881   2267.277344   Topic5  -5.2254   1.6371
# 2723  humanitarian   3674.928711   3688.599121   Topic5  -4.7421   1.6337
# 1443          huge   2302.538330   2303.414062   Topic5  -5.2096   1.6371
# 851       infected   3999.004883   4053.268555   Topic5  -4.6576   1.6240
#
# [188 rows x 6 columns], token_table=      Topic      Freq    Term
# term
# 670       4  0.999665  accuse
# 919       4  0.999778  action
# 2400      3  0.999618  active
# 286       2  0.999746   allow
# 335       1  0.999919     ask
# ...     ...       ...     ...
# 467       1  0.999945    work
# 1099      5  0.999816  worker
# 72        4  0.999913   world
# 28        2  0.999771   write
# 444       2  0.999811    year
#
# [174 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 5, 4, 1, 2])

# %%
#Importing the required files
country = 'UK/'
lda_model = models.LdaModel.load(root_path + country + '/lda.model')
corpus = pickle.load(open(root_path + country + 'corpus.pkl', 'rb'))
id2word = gensim.utils.SaveLoad.load(root_path + country + 'dictionary.gensim')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
#Visualising Topic Model
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.179632  0.045480       1        1  21.839474
# 2      0.181272  0.136465       2        1  20.365816
# 1     -0.093697 -0.388137       3        1  19.705952
# 3     -0.360645  0.194987       4        1  19.144066
# 0      0.093438  0.011205       5        1  18.944687, topic_info=            Term          Freq         Total Category  logprob  loglift
# 65        people  50352.000000  50352.000000  Default  30.0000  30.0000
# 150         test  33422.000000  33422.000000  Default  29.0000  29.0000
# 42         death  32756.000000  32756.000000  Default  28.0000  28.0000
# 1371    lockdown  28279.000000  28279.000000  Default  27.0000  27.0000
# 49    government  23300.000000  23300.000000  Default  26.0000  26.0000
# ...          ...           ...           ...      ...      ...      ...
# 12         thing   3137.872559   3138.663818   Topic5  -5.0368   1.6634
# 1186    guidance   3093.004395   3093.794434   Topic5  -5.0512   1.6634
# 1130        hour   3011.152100   3011.936523   Topic5  -5.0781   1.6634
# 308      control   3048.513428   3049.322266   Topic5  -5.0657   1.6634
# 8282        thug   5788.227539   5838.150391   Topic5  -4.4246   1.6551
#
# [185 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 212       4  0.999806     action
# 406       3  0.999880      allow
# 5807      2  0.001701  anonymous
# 5807      4  0.989925  anonymous
# 5807      5  0.008264  anonymous
# ...     ...       ...        ...
# 57        1  0.999925       work
# 800       2  0.998234     worker
# 800       3  0.001751     worker
# 68        1  0.999969      world
# 416       3  0.999766       year
#
# [163 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 3, 2, 4, 1])

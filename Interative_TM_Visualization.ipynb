# %% [markdown]
# ## Importing the required libraries

# %%
import pickle

# Gensim
import gensim, spacy, logging, warnings
from gensim import models, corpora

# !pip install pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()

warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# ## India

# %%
#Importing the required files
country = 'India/'
lda_model = models.LdaModel.load(root_path + country + '/lda.model')
corpus = pickle.load(open(root_path + country + 'corpus.pkl', 'rb'))

#Visualising Topic Model
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2     -0.061544  0.151427       1        1  20.978781
# 3      0.420699 -0.014218       2        1  20.315544
# 4     -0.124489  0.289584       3        1  20.094250
# 0     -0.106254 -0.155899       4        1  19.405071
# 1     -0.128413 -0.270893       5        1  19.206345, topic_info=              Term          Freq         Total Category  logprob  loglift
# 23            case  54659.000000  54659.000000  Default  30.0000  30.0000
# 25           virus  34678.000000  34678.000000  Default  29.0000  29.0000
# 35             new  30836.000000  30836.000000  Default  28.0000  28.0000
# 109         people  30025.000000  30025.000000  Default  27.0000  27.0000
# 18           death  26069.000000  26069.000000  Default  26.0000  26.0000
# ...            ...           ...           ...      ...      ...      ...
# 207           real   2229.718994   2230.535889   Topic5  -5.2290   1.6496
# ...

# %% [markdown]
# ## United Kingdom

# %%
#Importing the required files
country = 'UK/'
lda_model = models.LdaModel.load(root_path + country + '/lda.model')
corpus = pickle.load(open(root_path + country + 'corpus.pkl', 'rb'))

#Visualising Topic Model
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary=lda_model.id2word)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4      0.179632  0.045480       1        1  21.973286
# 2      0.181272  0.136465       2        1  20.102589
# 1     -0.093697 -0.388137       3        1  19.825159
# 3     -0.360645  0.194987       4        1  19.203232
# 0      0.093438  0.011205       5        1  18.895731, topic_info=            Term          Freq         Total Category  logprob  loglift
# 65        people  50639.000000  50639.000000  Default  30.0000  30.0000
# 150         test  33613.000000  33613.000000  Default  29.0000  29.0000
# 42         death  32845.000000  32845.000000  Default  28.0000  28.0000
# 1371    lockdown  28443.000000  28443.000000  Default  27.0000  27.0000
# 49    government  22991.000000  22991.000000  Default  26.0000  26.0000
# ...          ...           ...           ...      ...      ...      ...
# 12         thing   3128.668457   3129.459473   Topic5  -5.0368   1.6660
# ...
